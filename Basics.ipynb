# %%
print ('Hello World')
# Out:
# Hello World

# %%
name = "Anha"
age = 36
print (name)
print (age)
# Out:
# Anha
# 36

# %%
type (name)
# Out:
# str

# %%
type (age)
# Out:
# int

# %%
num1 = int(input("Enter 1st digit: "))
num2 = int(input("Enter 2nd digit: "))

sum = num1 + num2
diff = num1 - num2
pro = num1 + num2
div = num1 / num2

print("Sum: ", sum)
print("Difference ", diff)
print("Product ", pro)
print("Division ", div)
# Out:
# Sum:  6
# Difference  -2
# Product  6
# Division  0.5
