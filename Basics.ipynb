# %%
print ('Hello World')
# Out:
# Hello World

# %%
name = "Anha"
age = 36
print (name)
print (age)
# Out:
# Anha
# 36

# %%
type (name)
# Out:
# str

# %%
type (age)
# Out:
# int

# %%
num1 = int(input("Enter 1st digit: "))
num2 = int(input("Enter 2nd digit: "))

sum = num1 + num2
diff = num1 - num2
pro = num1 + num2
div = num1 / num2

print("Sum: ", sum)
print("Difference ", diff)
print("Product ", pro)
print("Division ", div)
# Out:
# Sum:  6
# Difference  -2
# Product  6
# Division  0.5

# %% [markdown]
# ## ⁠Write a Python program that takes a user input and prints it.
# ## ⁠Write a Python program to concatenate two strings.
# ## ⁠Write a Python program to calculate the square of a number.
# ## ⁠Write a Python program to find the sum of the first n natural numbers.
# ## ⁠Create variables of different data types: integer, float, string, and boolean. Print their values and types.
# ## ⁠Write a Python program to convert Celsius to Fahrenheit.
# ## Create a simple calculator using Python, take 2 user inputs, and perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation

# %%
# ## ⁠Write a Python program that takes a user input and prints it.
s = input("name:")
print(s)
# Out:
# anha

# %%
# ## ⁠Write a Python program to concatenate two strings.
str1 = "Hello"
str2 = "world"
str3 = str1+ " " + str2
print(str3)
# Out:
# Hello world

# %%
# ## ⁠Write a Python program to calculate the square of a number.
num1 = int(input("num1:"))
num2 = int(input("num2:"))
square = num1*num2
print("product of two numbers", square)
# Out:
# product of two numbers 4

# %%
# ## ⁠Write a Python program to find the sum of the first n natural numbers.
n = int(input("Enter a number: "))
sum = n*(n+1)//2
print("sum of natural number: ", sum)
# Out:
# sum of natural number:  15

# %%
# ## ⁠Create variables of different data types: integer, float, string, and boolean. Print their values and types.
m = 2
print(m)
print(type(m))
# Out:
# 2
# <class 'int'>

# %%
# ## ⁠Write a Python program to convert Celsius to Fahrenheit.
cf = int(input("Enter a temperature: "))
fahre = (cf * 9/5 + 32)
print("Temperature in fahrenheit", fahre)
# Out:
# Temperature in fahrenheit 32.0

# %%
# ## Create a simple calculator using Python, take 2 user inputs, and perform addition, subtraction
#  multiplication, division, floor division, modulus, and exponentiation
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
sum = num1 + num2
sub = num1 - num2
div = num1 / num2
mul = num1 * num2
floordiv = num1 // num2
mod = num1 % num2
expo = num1 ** num2

print("Addition", sum)

print("Subtraction", sub)

print("Division", div)

print("multiplication", mul)

print("floordivision", floordiv)

print("modulus", mod)

print("exponential", expo)
# Out:
# Addition 6
# Subtraction -2
# Division 0.5
# multiplication 8
# floordivision 0
# modulus 2
# exponential 16
